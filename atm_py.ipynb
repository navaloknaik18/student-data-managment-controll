# %% [markdown]
# <a href="https://colab.research.google.com/github/navaloknaik18/student-data-managment-controll/blob/main/atm_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("good morning")
username = "navalok"
password = "0408nava"
balance = 10000
name = str(input("please enter your name ;"))
pass1 = str(input("please enter your password;"))

if username == name:
  if password == pass1:
    print("welcome ",username)
    print(" choose the option to proceed;")
    print("1.checkbalance")
    print("2.addbalance")
    print("3.withdraw")
    print("4.exit")
    choice = int(input("enter the option 1 or 2 or 3 or 4;"))
    if choice in (1,2,3,4):
      if choice == 1:
        print("your balance is",balance)
      elif choice == 2:
        print("enter the amount to add")
        amt = int(input("enter amount in number;"))
        new_bal = amt + balance
        print("the new balance is",new_bal)
      elif choice == 3:
        amt1 = int(input("enter the amount you want withdraw ;"))
        if amt1 > balance:
          print("invalid balance")
        else:
          new_bal2 = balance - amt1
          print("your cuureent balance is ..",new_bal2)
      else:
        print("thanks for choosing us..........")
    else:
      print("please enter the valid option")
# Out:
# good morning
# please enter your name ;navalok
# please enter your password;0408nava
# welcome  navalok
#  choose the option to proceed;
# 1.checkbalance
# 2.addbalance
# 3.withdraw
# 4.exit
# enter the option 1 or 2 or 3 or 4;2
# enter the amount to add
# enter amount in number;1000
# the new balance is 11000
