# %% [markdown]
# <a href="https://colab.research.google.com/github/navaloknaik18/student-data-managment-controll/blob/main/cal_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hey hi welcome to  madyX CALCULATER")
def add(a,b):
  return a + b
def sub(a,b):
  if a > b:
    return  a - b
  else:
    return  b - a
def mul(a,b):
  return  a*b
def div(a,b):
  if a == 0 and b == 0 :
    return "errrorr"
  elif a >b:
    return a/b

  else:
    return  b/a
print("ok buddy lets go........")

print("choose the operation  you want perform,\n add,\n sub,\n multiply,\n divide")
choose = str(input("enter the name of the operation you want to perform :"))
if choose == "add":
   addition = add(int(input("enter the value of a :")),int(input("enter the value of b: ")))
   print(addition)
elif choose == "sub":
     subtract = sub(int(input("enter the value of a :")),int(input("enter the value of b: ")))
     print(subtract)
elif choose == "multiply":
     multi = mul(int(input("enter the value of a :")),int(input("enter the value of b : ")))
     print(multi)
elif choose == "divide":
     divi = div(int(input("enter the value of a :")),int(input("enter the value of b : ")))
     print(divi)
else :
  print("error🤒")
